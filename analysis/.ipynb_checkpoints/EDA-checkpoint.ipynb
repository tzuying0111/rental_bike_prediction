# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# Reading in file (it came in csv file but I firstly converted it into pickle file for easy access). Column names was corrected

# %%
df = pd.read_pickle('../data/SeoulBikeData.pkl')

# %%
df.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature  Humidity  Wind speed  Visibility  Dew point temperature  Solar Radiation  Rainfall  Snowfall Seasons     Holiday Functioning Day
# 0  1/12/2017                254     0         -5.2        37         2.2        2000                  -17.6              0.0       0.0       0.0  Winter  No Holiday             Yes
# 1  1/12/2017                204     1         -5.5        38         0.8        2000                  -17.6              0.0       0.0       0.0  Winter  No Holiday             Yes
# 2  1/12/2017                173     2         -6.0        39         1.0        2000                  -17.7              0.0       0.0       0.0  Winter  No Holiday             Yes
# 3  1/12/2017                107     3         -6.2        40         0.9        2000                  -17.6              0.0       0.0       0.0  Winter  No Holiday             Yes
# ...

# %% [markdown]
# Checking in dataframe inforamtion. There are no missing values in any of the features -- Great.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
# Date                     8760 non-null object
# Rented Bike Count        8760 non-null int64
# Hour                     8760 non-null int64
# Temperature              8760 non-null float64
# Humidity                 8760 non-null int64
# Wind speed               8760 non-null float64
# Visibility               8760 non-null int64
# Dew point temperature    8760 non-null float64
# Solar Radiation          8760 non-null float64
# Rainfall                 8760 non-null float64
# Snowfall                 8760 non-null float64
# Seasons                  8760 non-null object
# Holiday                  8760 non-null object
# Functioning Day          8760 non-null object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB

# %%
df.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature  Humidity  Wind speed  Visibility  Dew point temperature  Solar Radiation  Rainfall  Snowfall Seasons     Holiday Functioning Day
# 0  1/12/2017                254     0         -5.2        37         2.2        2000                  -17.6              0.0       0.0       0.0  Winter  No Holiday             Yes
# 1  1/12/2017                204     1         -5.5        38         0.8        2000                  -17.6              0.0       0.0       0.0  Winter  No Holiday             Yes
# 2  1/12/2017                173     2         -6.0        39         1.0        2000                  -17.7              0.0       0.0       0.0  Winter  No Holiday             Yes
# 3  1/12/2017                107     3         -6.2        40         0.9        2000                  -17.6              0.0       0.0       0.0  Winter  No Holiday             Yes
# ...

# %%
df.shape
# Out:
# (8760, 14)

# %%
df.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature', 'Humidity', 'Wind speed', 'Visibility', 'Dew point temperature', 'Solar Radiation', 'Rainfall', 'Snowfall', 'Seasons', 'Holiday', 'Functioning Day'], dtype='object')

# %% [markdown]
# renaming columns by replacing space with underscore

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['Date', 'Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity', 'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation', 'Rainfall', 'Snowfall', 'Seasons', 'Holiday', 'Functioning_Day'], dtype='object')

# %% [markdown]
# Identifying categorical variables

# %%
cat_col = ['Seasons', 'Holiday', 'Functioning_Day']

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %% [markdown]
# Checking the date range of the data set

# %%
print('date range:', df['Date'].min(), '-', df['Date'].max())
# Out:
# date range: 2017-01-12 00:00:00 - 2018-12-11 00:00:00

# %% [markdown]
# Getting the continuous variables

# %%
non_str_col = df.describe().columns

# %%
non_str_col
# Out:
# Index(['Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity', 'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation', 'Rainfall', 'Snowfall'], dtype='object')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# First I'd like to check on the overview of the data set by looking at the distributions of each continuous variables

# %%
np.round(df.describe(), 3)
# Out:
#        Rented_Bike_Count      Hour  Temperature  Humidity  Wind_speed  Visibility  Dew_point_temperature  Solar_Radiation  Rainfall  Snowfall        yr       mon
# count           8760.000  8760.000     8760.000  8760.000    8760.000    8760.000               8760.000         8760.000  8760.000  8760.000  8760.000  8760.000
# mean             704.602    11.500       12.883    58.226       1.725    1436.826                  4.074            0.569     0.149     0.075  2017.915     6.526
# std              644.997     6.923       11.945    20.362       1.036     608.299                 13.060            0.869     1.128     0.437     0.279     3.448
# min                0.000     0.000      -17.800     0.000       0.000      27.000                -30.600            0.000     0.000     0.000  2017.000     1.000
# 25%              191.000     5.750        3.500    42.000       0.900     940.000                 -4.700            0.000     0.000     0.000  2018.000     4.000
# ...

# %% [markdown]
# Creating the plotting function

# %%
def plt_hist(col):
    f, axes = plt.subplots(1, 2, figsize=(10, 4))
    f.tight_layout()
    sns.distplot(df[col], ax=axes[0])
    sns.boxplot(df[col], orient='v', ax=axes[1])
    plt.show()

# %% [markdown]
# In the below graphs, I can look at the distributions of each continuous variables one by one. Looks like Rental bike Count (the target variable) is left skewed, with some extreme cases in some of the hours. The data is skewed due to the nature of the weather in Korea.

# %%
for col in non_str_col:
    plt_hist(col)

# %%
cat_col
# Out:
# ['Seasons', 'Holiday', 'Functioning_Day']

# %%
cat_df = df.select_dtypes(include=['object', 'datetime', 'integer']).copy()
cat_df = cat_df.drop(['Humidity', 'Visibility'], axis=1)
cat_df = cat_df.sort_values(['Date', 'Hour'])
cat_df.tail()
# Out:
#            Date  Rented_Bike_Count  Hour Seasons     Holiday Functioning_Day    yr  mon
# 8323 2018-12-11               1466    19  Autumn  No Holiday             Yes  2018   12
# 8324 2018-12-11               1292    20  Autumn  No Holiday             Yes  2018   12
# 8325 2018-12-11               1189    21  Autumn  No Holiday             Yes  2018   12
# 8326 2018-12-11               1023    22  Autumn  No Holiday             Yes  2018   12
# 8327 2018-12-11                702    23  Autumn  No Holiday             Yes  2018   12

# %% [markdown]
# Now, looking at the categorical variables. In the dataset, there are three categorical variables, including Holidays, Functioning days, and Seasons. The summary shows that we have equal numbers of data across each season, and most of the days are functioning day and non-holiday.

# %%
pd.crosstab(index=cat_df['Holiday'], columns='count')
# Out:
# col_0       count
# Holiday
# Holiday       432
# No Holiday   8328

# %%
pd.crosstab(index=cat_df['Functioning_Day'], columns='count')
# Out:
# col_0            count
# Functioning_Day
# No                 295
# Yes               8465

# %%
pd.crosstab(index=cat_df['Seasons'], columns='count')
# Out:
# col_0    count
# Seasons
# Autumn    2184
# Spring    2208
# Summer    2208
# Winter    2160

# %% [markdown]
# # Bivariate Analysis

# %%
df['yr'] = df['Date'].dt.year
df['mon'] = df['Date'].dt.month

# %% [markdown]
# I'd like to see the relationship between the rental bike counts and the hour of the day. the following graph shows that in average, people rented bikes more during rush hours (8 am and 6 pm), and people tend to rent more bike in the afternoon/evening than in the morning.

# %%
plt.title('Hour vs bike count')
plt.xlabel('Hour')
plt.ylabel('Bike count')
tmp = df.groupby('Hour')['Rented_Bike_Count'].mean().reset_index()
plt.bar(tmp.Hour, tmp.Rented_Bike_Count)
plt.show()

# %% [markdown]
# Intersting finding: The data set doesn't have complete 2017 data, hence when plotting time series, it is a bit difficult to read.

# %%
# Time series
def plt_time_series(col):
    plt.title(col)
    plt.xlabel('Date')
    plt.ylabel(col)
    tmp = df[df['yr']==2018].groupby(['Date'])[col].mean()
    plt.plot(tmp.index, tmp)
    plt.show()

# %%
df = df.sort_values('Date')
for col in ['Rented_Bike_Count', 'Temperature', 'Humidity']:
    plt_time_series(col)

# %%
corr = df[['Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity', 'Wind_speed', 'Visibility']].corr()
plt.figure(figsize = (6,6))
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,
           annot=True, fmt='.2f', linewidths=.30)
plt.title('Correlation of MainDF Features', y =1.05,  size=15)
# Out:
# Text(0.5, 1.05, 'Correlation of MainDF Features')

# %%
def scatter_plt(col):
    sns.lmplot(col, 'Rented_Bike_Count', data=df)
    plt.xlabel(col)
    plt.title(col)
    plt.ylabel('Rented Bike Count')
    plt.show()

# %%
for col in non_str_col:
    if col not in ['Rented_Bike_Count', 'Hour']:
        
        scatter_plt(col)

# %% [markdown]
# In the above scatter plots, we know that people have less tedency to rent bikes on snow and rain days. There is a slight positive correlation in solar radiation, showing that people tends to rent a bike when there's sunshine

# %% [markdown]
# Wanted to look at the relationship between the bike count and seasons, and found that in summer and autumns people like to ride the bikes more.

# %%
seasn = df.groupby(['Seasons'])['Rented_Bike_Count'].mean()
print(seasn)
# Out:
# Seasons
# Autumn     819.597985
# Spring     730.031250
# Summer    1034.073370
# Winter     225.541204
# Name: Rented_Bike_Count, dtype: float64
